# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import nltk

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\smit1\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Load the dataset
df = pd.read_csv('books.csv')

# %%
df
# Out:
#                                                    title  \
# 0              Harry Potter and the Order of the Phoenix
# 1                                               Twilight
# 2                                         The Book Thief
# 3                                            Animal Farm
# 4      J.R.R. Tolkien 4-Book Boxed Set: The Hobbit an...
# ...                                                  ...
# 23255  Heal Your Body: The Mental Causes for Physical...
# 23256                                  Attracted to Fire
# 23257                                       Unbelievable
# 23258                                             Marked
# 23259                                        Wayward Son
#
#                                                   author  \
# 0              J.K. Rowling, Mary GrandPré (Illustrator)
# 1                                        Stephenie Meyer
# 2                        Markus Zusak (Goodreads Author)
# 3      George Orwell, Russell Baker (Preface), C.M. W...
# 4                                         J.R.R. Tolkien
# ...                                                  ...
# 23255                                      Louise L. Hay
# 23256                     DiAnn Mills (Goodreads Author)
# 23257                   Sherry Gammon (Goodreads Author)
# 23258                  Kim Richardson (Goodreads Author)
# 23259  Tom Pollack (Goodreads Author), John Loftus (G...
#
#                                              description language  \
# 0      There is a door at the end of a silent corrido...  English
# 1      About three things I was absolutely positive.\...  English
# 2      Librarian's note: An alternate cover edition c...  English
# 3      Librarian's note: There is an Alternate Cover ...  English
# 4      This four-volume, boxed set contains J.R.R. To...  English
# ...                                                  ...      ...
# 23255  Heal Your Body is a fresh and easy step-by-ste...  English
# 23256  Special Agent Meghan Connors' dream of one day...  English
# 23257  Lilah Lopez Dreser's in town to take care of u...  English
# 23258  --READERS FAVORITE AWARDS WINNER 2011--Sixteen...  English
# 23259  A POWERFUL TREMOR UNEARTHS AN ANCIENT SECRETBu...  English
#
#                                                   genres  \
# 0      ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 1      ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 2      ['Historical Fiction', 'Fiction', 'Young Adult...
# 3      ['Classics', 'Fiction', 'Dystopia', 'Fantasy',...
# 4      ['Fantasy', 'Fiction', 'Classics', 'Adventure'...
# ...                                                  ...
# 23255  ['Self Help', 'Health', 'Nonfiction', 'Spiritu...
# 23256  ['Christian Fiction', 'Christian', 'Suspense',...
# 23257  ['Romance', 'Young Adult', 'Contemporary', 'Co...
# 23258  ['Fantasy', 'Young Adult', 'Paranormal', 'Ange...
# 23259  ['Fiction', 'Mystery', 'Historical Fiction', '...
#
#                                               characters  \
# 0      ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...
# 1      ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...
# 2      ['Liesel Meminger', 'Hans Hubermann', 'Rudy St...
# 3      ['Snowball', 'Napoleon', 'Clover', 'Boxer', 'O...
# 4      ['Frodo Baggins', 'Gandalf', 'Bilbo Baggins', ...
# ...                                                  ...
# 23255                                                 []
# 23256                                                 []
# 23257                                                 []
# 23258                                                 []
# 23259                                                 []
#
#                   bookFormat pages                  publisher  \
# 0                  Paperback   870            Scholastic Inc.
# 1                  Paperback   501  Little, Brown and Company
# 2                  Hardcover   552            Alfred A. Knopf
# 3      Mass Market Paperback   141            Signet Classics
# 4      Mass Market Paperback  1728           Ballantine Books
# ...                      ...   ...                        ...
# 23255              Paperback    96                  Hay House
# 23256              Paperback   416   Tyndale House Publishers
# 23257              Paperback   360    Wordpaintings Unlimited
# 23258              Paperback   280                CreateSpace
# 23259              Paperback   507        Cascada Productions
#
#               publishDate                                             awards  \
# 0              2004/09/28  ['Bram Stoker Award for Works for Young Reader...
# 1              2006/09/06  ['Georgia Peach Book Award (2007)', 'Buxtehude...
# 2              2006/03/14  ['National Jewish Book Award for Children’s an...
# 3              1996/04/28  ['Prometheus Hall of Fame Award (2011)', 'Retr...
# 4              2012/09/25                                                 []
# ...                   ...                                                ...
# 23255    January 1st 1984                                                 []
# 23256    October 1st 2011  ['HOLT Medallion by Virginia Romance Writers N...
# 23257     April 11th 2013                                                 []
# 23258     March 18th 2011            ["Readers' Favorite Book Award (2011)"]
# 23259  September 1st 2011                                                 []
#
#                                                  setting  \
# 0      ['Hogwarts School of Witchcraft and Wizardry (...
# 1      ['Forks, Washington (United States)', 'Phoenix...
# 2                      ['Molching (Germany)', 'Germany']
# 3                          ['England', 'United Kingdom']
# 4                                       ['Middle-earth']
# ...                                                  ...
# 23255                                                 []
# 23256                     ['West Texas (United States)']
# 23257            ['Port Fare, New York (United States)']
# 23258                                                 []
# 23259                                                 []
#
#                                                 coverImg     price  \
# 0      https://i.gr-assets.com/images/S/compressed.ph...   630.990
# 1      https://i.gr-assets.com/images/S/compressed.ph...   179.550
# 2      https://i.gr-assets.com/images/S/compressed.ph...   324.900
# 3      https://i.gr-assets.com/images/S/compressed.ph...   377.910
# 4      https://i.gr-assets.com/images/S/compressed.ph...  1808.325
# ...                                                  ...       ...
# 23255  https://i.gr-assets.com/images/S/compressed.ph...   389.880
# 23256  https://i.gr-assets.com/images/S/compressed.ph...   474.525
# 23257  https://i.gr-assets.com/images/S/compressed.ph...  1639.890
# 23258  https://i.gr-assets.com/images/S/compressed.ph...   630.135
# 23259  https://i.gr-assets.com/images/S/compressed.ph...   244.530
#
#                     genre1          genre2                 genre3  \
# 0                 Fantasy'   'Young Adult'              'Fiction'
# 1             Young Adult'       'Fantasy'              'Romance'
# 2      Historical Fiction'       'Fiction'          'Young Adult'
# 3                Classics'       'Fiction'             'Dystopia'
# 4                 Fantasy'       'Fiction'             'Classics'
# ...                    ...             ...                    ...
# 23255           Self Help'        'Health'           'Nonfiction'
# 23256   Christian Fiction'     'Christian'             'Suspense'
# 23257             Romance'   'Young Adult'         'Contemporary'
# 23258             Fantasy'   'Young Adult'           'Paranormal'
# 23259             Fiction'       'Mystery'   'Historical Fiction'
#
#                         genre4                      genre5  main_genre
# 0                      'Magic'                 'Childrens'     Fantasy
# 1                   'Vampires'                   'Fiction'    Children
# 2                 'Historical'                  'Classics'     Fiction
# 3                    'Fantasy'                'Literature'      Others
# 4                  'Adventure'   'Science Fiction Fantasy'     Fantasy
# ...                        ...                         ...         ...
# 23255           'Spirituality'                'Psychology'  Nonfiction
# 23256                'Romance'                   'Mystery'     Romance
# 23257   'Contemporary Romance'                  'Suspense'     Romance
# 23258                 'Angels'                   'Romance'     Fantasy
# 23259              'Adventure'         'Christian Fiction'      Others
#
# [23260 rows x 20 columns]

# %%
df.to_csv('books.csv', index=False)

# %%
df.to_json('books.json',orient='records')

# %%
df.to_csv()

# %%
# Select relevant fields
df = df[['title', 'author', 'description', 'language', 'genres', 'publisher', 'awards', 'setting', 'main_genre']]

# %%
# Remove English stop words from the description and setting
stop_words = set(stopwords.words('english'))

# %%
df

# %%
def preprocess_text(text):
    # Tokenize and remove stop words
    return ' '.join([word for word in text.split() if word.lower() not in stop_words])

# %%
# Apply preprocessing to description and setting
df['description'] = df['description'].apply(preprocess_text)
df['setting'] = df['setting'].apply(preprocess_text)

# %%
# Combine description and setting for the recommendation model
df['combined_text'] = df['description'] + ' ' + df['setting']

# %%
# Initialize TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(df['combined_text'])

# %%
# Compute cosine similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
# Function to get recommendations
def recommend_books(title, num_recommendations=5):
    # Get index of the book that matches the title
    idx = df[df['title'] == title].index[0]

    # Get the pairwise similarity scores of all books with that book
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the books based on similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the most similar books
    sim_scores = sim_scores[0:num_recommendations + 1]

    # Get the book indices
    book_indices = [i[0] for i in sim_scores]

    # Return the top most similar books
    return df.iloc[book_indices][['title', 'author', 'main_genre']]

# %%
# Example usage
recommended_books = recommend_books("The Alchemist", num_recommendations=5)  # Replace with an actual book title
print(recommended_books)

# %%
# title
# auther
# description
# language
# genres
# publisher
# awards
# setting
# main_genre
